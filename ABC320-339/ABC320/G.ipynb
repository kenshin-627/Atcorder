# %%
from functools import lru_cache
import sys
sys.setrecursionlimit(10**9)
# input = sys.stdin.readline
from decimal import Decimal
from functools import cmp_to_key
from collections import Counter
from itertools import permutations
from itertools import combinations
from itertools import combinations_with_replacement
from itertools import product
from itertools import accumulate
from itertools import groupby
from itertools import pairwise
from copy import deepcopy
import networkx as nx
import networkx.algorithms as nxa
import numpy as np
import math
import heapq
from collections import OrderedDict
import bisect
from collections import deque

from collections import defaultdict

def main():
    N,M = map(int,input().split())
    S = []
    for _ in range(N):
        S.append(input())
    # 数字numが何回出てきたか
    cnt_dict = defaultdict(int)
    # j個目のリールが数字numを含むかどうか
    num_set = [set() for _ in range(N)]
    for i in range(M):
        tmp_set = set()
        for j in range(N):
            # j個目のリールのi番目の文字
            if S[j][i] in num_set[j]:
                continue
            tmp_set.add(S[j][i])
            num_set[j].add(S[j][i])
        for s in tmp_set:
            cnt_dict[s] += 1
            if cnt_dict[s] == N:
                print(i)
                return
    inter = set.intersection(*num_set)
    if inter == set():
        print(-1)
        return
    # 出てきた回数が一番大きいものをNにならないようにかける
    max_inter = 0
    max_cnt = 0
    for s in inter:
        if cnt_dict[s] > max_cnt:
            max_cnt = cnt_dict[s]
            max_inter = s
    ans = max_cnt * (M // max_cnt)
    print(max_cnt)
    print(ans)
    if ans == M:
        ans -= max_cnt
    # j個目のリールが数字numを含むかどうか
    num_set = [set() for _ in range(N)]
    for i in range(M):
        tmp_set = set()
        for j in range(N):
            # j個目のリールのi番目の文字
            if S[j][i] in num_set[j]:
                continue
            tmp_set.add(S[j][i])
            num_set[j].add(S[j][i])
        for s in tmp_set:
            cnt_dict[s] += 1
            if cnt_dict[s] == N:
                print(i+ans)
                return
    
if __name__ == "__main__":
    main()
# Out:
# -1
