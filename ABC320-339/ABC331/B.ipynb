# %%
from functools import lru_cache
import sys
sys.setrecursionlimit(10**9) # 再帰関数の呼び出し制限
sys.set_int_max_str_digits(10**9) # int,str変換の10進数での最大桁数を指定
# input = sys.stdin.readline
# import pypyjit
# pypyjit.set_param('max_unroll_recursion=-1') # pypyの再帰高速化
from decimal import Decimal
from functools import cmp_to_key
from collections import Counter
from itertools import permutations
from itertools import combinations
from itertools import combinations_with_replacement
from itertools import product
from itertools import accumulate
from itertools import groupby
from itertools import pairwise
from more_itertools import distribute
from copy import deepcopy
import networkx as nx
import networkx.algorithms as nxa
import numpy as np
import math
from collections import OrderedDict
from sortedcontainers import SortedSet
from sortedcontainers import SortedList
from sortedcontainers import SortedDict
from heapq import *
from bisect import *
from collections import deque

from collections import defaultdict

def main():
    # 6,8,12
    N,S,M,L = map(int,input().split())
    cost = defaultdict(lambda:float("inf"))
    q = [0]
    cost[0] = 0
    ans = float("inf")
    while q:
        v = q.pop()
        if cost[v+6] > cost[v] + S:
            cost[v+6] = cost[v] + S
            if v+6 >= N:
                ans = min(ans,cost[v+6])
            else:
                q.append(v+6)
        if cost[v+8] > cost[v] + M:
            cost[v+8] = cost[v] + M
            if v+8 >= N:
                ans = min(ans,cost[v+8])
            else:
                q.append(v+8)
        if cost[v+12] > cost[v] + L:
            cost[v+12] = cost[v] + L
            if v+12 >= N:
                ans = min(ans,cost[v+12])
            else:
                q.append(v+12)
    print(ans)


if __name__ == "__main__":
    main()
