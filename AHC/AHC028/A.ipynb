# %%
'''
S: 6382, C: 3618
S: 7100, C: 2900
S: 7162, C: 2838
S: 7167, C: 2833
S: 7199, C: 2801
'''

# %%
from heapq import *
from collections import deque
from collections import defaultdict

def main():
    # N,M = 15,200
    N,M = map(int,input().split())
    si,sj = map(int,input().split())
    A = [list(input()) for _ in range(N)]
    t = [input() for _ in range(M)]
    # -----------------あとで改善する(上位5座標)-----------------
    # 各座標から各文字までの距離が短い順に上位5座標，座標:文字:[(距離,座標)] (heapで最大値を管理して，5個以上の時はpopする)
    ij2char2dkl = defaultdict(lambda:defaultdict(list))
    for i in range(N):
        for j in range(N):
            for k in range(N):
                for l in range(N):
                    # if i == k and j == l:
                    #     continue
                    d = abs(i-k) + abs(j-l)
                    if len(ij2char2dkl[(i,j)][A[k][l]]) < 5:
                        heappush(ij2char2dkl[(i,j)][A[k][l]],(-d,(k,l)))
                    else:
                        heappushpop(ij2char2dkl[(i,j)][A[k][l]],(-d,(k,l)))
    # 文字:[座標]の辞書
    char2ij = defaultdict(list)
    for i in range(N):
        for j in range(N):
            char2ij[A[i][j]].append((i,j))
    # t[i][0]は全ての座標，t[i][j]はt[i][j-1]から近い座標5個まで記録して，各t[i][0]から始めた時のt[i][4]までの最短距離と座標を記録
    # tのi番目の文字列は(j,k)から始めた時，距離lで，(m,n)に行ける，i番目:t[i][0]の座標:(距離,t[i][4]までの座標)
    ti2jk2dlm = defaultdict(lambda:defaultdict(lambda:(1000,[])))
    for i in range(M):
        for k,l in char2ij[t[i][0]]:
            # q: j文字目, 総距離d, [(k,l)]座標
            q = deque([(0,0,[(k,l)])])
            while q:
                j,d,mnlist = q.popleft()
                m,n = mnlist[-1]
                for d_,(o,p) in ij2char2dkl[(m,n)][t[i][j+1]]:
                    d_ = -d_
                    if j+1 == len(t[i])-1:
                        if d+d_ < ti2jk2dlm[i][(k,l)][0]:
                            ti2jk2dlm[i][(k,l)] = (d+d_,mnlist+[(o,p)])
                    else:
                        q.append((j+1,d+d_,mnlist+[(o,p)]))
    # これで各tについて，t[i][0]の文字の座標から始めた時のt[i][4]の座標までの短い距離と座標がわかる
    # -----------------あとで改善する(Mの順番)-----------------
    # まずはMの順番はそのままで貪欲に近い座標を選んでいく
    nowi,nowj = si,sj
    print(nowi,nowj)
    for i in range(M):
        # 今の座標からt[i][0]までの距離とt[i][0]からt[i][4]までの距離を足したものが最小になる座標を選ぶ
        min_d = 1000
        min_ij_list = []
        for k,l in char2ij[t[i][0]]:
            if ti2jk2dlm[i][(k,l)][0] + abs(nowi-k) + abs(nowj-l) < min_d:
                min_d = ti2jk2dlm[i][(k,l)][0] + abs(nowi-k) + abs(nowj-l)
                min_ij_list = ti2jk2dlm[i][(k,l)][1]
        for kl in min_ij_list:
            print(*kl)
        nowi,nowj = min_ij_list[-1]

if __name__ == "__main__":
    main()

# %%
from heapq import *
from collections import deque
from collections import defaultdict

def main():
    # N,M = 15,200
    N,M = map(int,input().split())
    si,sj = map(int,input().split())
    A = [list(input()) for _ in range(N)]
    t = [input() for _ in range(M)]
    # -----------------あとで改善する(上位5座標)-----------------
    # 各座標から各文字までの距離が短い順に上位5座標，座標:文字:[(距離,座標)] (heapで最大値を管理して，5個以上の時はpopする)
    ij2char2dkl = defaultdict(lambda:defaultdict(list))
    for i in range(N):
        for j in range(N):
            for k in range(N):
                for l in range(N):
                    # if i == k and j == l:
                    #     continue
                    d = abs(i-k) + abs(j-l)
                    if len(ij2char2dkl[(i,j)][A[k][l]]) < 5:
                        heappush(ij2char2dkl[(i,j)][A[k][l]],(-d,(k,l)))
                    else:
                        heappushpop(ij2char2dkl[(i,j)][A[k][l]],(-d,(k,l)))
    # 文字:[座標]の辞書
    char2ij = defaultdict(list)
    for i in range(N):
        for j in range(N):
            char2ij[A[i][j]].append((i,j))
    # t[i][0]は全ての座標，t[i][j]はt[i][j-1]から近い座標5個まで記録して，各t[i][0]から始めた時のt[i][4]までの最短距離と座標を記録
    # tのi番目の文字列は(j,k)から始めた時，距離lで，(m,n)に行ける，i番目:t[i][0]の座標:(距離,t[i][4]までの座標)
    ti2jk2dlm = defaultdict(lambda:defaultdict(lambda:(1000,[])))
    for i in range(M):
        for k,l in char2ij[t[i][0]]:
            # q: j文字目, 総距離d, [(k,l)]座標
            q = deque([(0,0,[(k,l)])])
            while q:
                j,d,mnlist = q.popleft()
                m,n = mnlist[-1]
                for d_,(o,p) in ij2char2dkl[(m,n)][t[i][j+1]]:
                    d_ = -d_
                    if j+1 == len(t[i])-1:
                        if d+d_ < ti2jk2dlm[i][(k,l)][0]:
                            ti2jk2dlm[i][(k,l)] = (d+d_,mnlist+[(o,p)])
                    else:
                        q.append((j+1,d+d_,mnlist+[(o,p)]))
    # これで各tについて，t[i][0]の文字の座標から始めた時のt[i][4]の座標までの短い距離と座標がわかる
    # -----------------あとで改善する(Mの順番)-----------------
    # 今の座標からt[i][0]までの距離とt[i][0]からt[i][4]までの距離を足したものが最小になるiと座標を選ぶ
    nowi,nowj = si,sj
    print(nowi,nowj)
    seen = set()
    for j in range(M):
        min_j = -1
        min_d_ = 1000
        min_ij_list_ = []
        for i in range(M):
            if i in seen:
                continue
            # 今の座標からt[i][0]までの距離とt[i][0]からt[i][4]までの距離を足したものが最小になる座標を選ぶ
            ti0 = t[i][0]
            min_d = 1000
            min_ij_list = []
            for k,l in char2ij[ti0]:
                if ti2jk2dlm[i][(k,l)][0] + abs(nowi-k) + abs(nowj-l) < min_d:
                    min_d = ti2jk2dlm[i][(k,l)][0] + abs(nowi-k) + abs(nowj-l)
                    min_ij_list = ti2jk2dlm[i][(k,l)][1]
            if min_d < min_d_:
                min_d_ = min_d
                min_ij_list_ = min_ij_list
                min_j = i
        for kl in min_ij_list_:
            print(*kl)
        nowi,nowj = min_ij_list_[-1]
        seen.add(min_j)

if __name__ == "__main__":
    main()

# %%
from heapq import *
from collections import deque
from collections import defaultdict

def main():
    # N,M = 15,200
    N,M = map(int,input().split())
    si,sj = map(int,input().split())
    A = [list(input()) for _ in range(N)]
    t = [input() for _ in range(M)]
    # -----------------あとで改善する(上位5座標)-----------------
    # 各座標から各文字までの距離が短い順に上位5座標，座標:文字:[(距離,座標)] (heapで最大値を管理して，5個以上の時はpopする)
    ij2char2dkl = defaultdict(lambda:defaultdict(list))
    for i in range(N):
        for j in range(N):
            for k in range(N):
                for l in range(N):
                    # if i == k and j == l:
                    #     continue
                    d = abs(i-k) + abs(j-l)
                    if len(ij2char2dkl[(i,j)][A[k][l]]) < 5:
                        heappush(ij2char2dkl[(i,j)][A[k][l]],(-d,(k,l)))
                    else:
                        heappushpop(ij2char2dkl[(i,j)][A[k][l]],(-d,(k,l)))
    # 文字:[座標]の辞書
    char2ij = defaultdict(list)
    for i in range(N):
        for j in range(N):
            char2ij[A[i][j]].append((i,j))
    # t[i][0]は全ての座標，t[i][j]はt[i][j-1]から近い座標5個まで記録して，各t[i][0]から始めた時のt[i][4]までの最短距離と座標を記録
    # tのi番目の文字列は(j,k)から始めた時，距離lで，(m,n)に行ける，i番目:t[i][0]の座標:(距離,t[i][4]までの座標)
    ti2jk2dlm = defaultdict(lambda:defaultdict(lambda:(1000,[])))
    for i in range(M):
        for k,l in char2ij[t[i][0]]:
            # q: j文字目, 総距離d, [(k,l)]座標
            q = deque([(0,0,[(k,l)])])
            while q:
                j,d,mnlist = q.popleft()
                m,n = mnlist[-1]
                for d_,(o,p) in ij2char2dkl[(m,n)][t[i][j+1]]:
                    d_ = -d_
                    if j+1 == len(t[i])-1:
                        if d+d_ < ti2jk2dlm[i][(k,l)][0]:
                            ti2jk2dlm[i][(k,l)] = (d+d_,mnlist+[(o,p)])
                    else:
                        q.append((j+1,d+d_,mnlist+[(o,p)]))
    # これで各tについて，t[i][0]の文字の座標から始めた時のt[i][4]の座標までの短い距離と座標がわかる
    # -----------------あとで改善する(Mの順番)-----------------
    # 今の座標からt[i][0]までの距離とt[i][0]からt[i][4]までの距離を足したものが最小になるiと座標を選ぶ
    nowi,nowj = si,sj
    print(nowi,nowj)
    seen = set()
    for j in range(M):
        min_j = -1
        min_d_ = 1000
        min_ij_list_ = []
        for i in range(M):
            if i in seen:
                continue
            # 今の座標からt[i][0]までの距離とt[i][0]からt[i][4]までの距離を足したものが最小になる座標を選ぶ
            ti0 = t[i][0]
            min_d = 1000
            min_ij_list = []
            for k,l in char2ij[ti0]:
                if ti2jk2dlm[i][(k,l)][0] + abs(nowi-k) + abs(nowj-l) < min_d:
                    min_d = ti2jk2dlm[i][(k,l)][0] + abs(nowi-k) + abs(nowj-l)
                    min_ij_list = ti2jk2dlm[i][(k,l)][1]
            if min_d < min_d_:
                min_d_ = min_d
                min_ij_list_ = min_ij_list
                min_j = i
        # 最後の文字と最初の文字同じなら省略
        for i,kl in enumerate(min_ij_list_):
            if i == 0 and nowi == kl[0] and nowj == kl[1]:
                continue
            print(*kl)
        nowi,nowj = min_ij_list_[-1]
        seen.add(min_j)

if __name__ == "__main__":
    main()

# %%
from heapq import *
from collections import deque
from collections import defaultdict

def main():
    # N,M = 15,200
    out = []
    N,M = map(int,input().split())
    si,sj = map(int,input().split())
    A = [list(input()) for _ in range(N)]
    t = [input() for _ in range(M)]
    # -----------------あとで改善する(上位5座標)-----------------
    # 各座標から各文字までの距離が短い順に上位5座標，座標:文字:[(距離,座標)] (heapで最大値を管理して，5個以上の時はpopする)
    ij2char2dkl = defaultdict(lambda:defaultdict(list))
    for i in range(N):
        for j in range(N):
            for k in range(N):
                for l in range(N):
                    # if i == k and j == l:
                    #     continue
                    d = abs(i-k) + abs(j-l)
                    if len(ij2char2dkl[(i,j)][A[k][l]]) < 5:
                        heappush(ij2char2dkl[(i,j)][A[k][l]],(-d,(k,l)))
                    else:
                        heappushpop(ij2char2dkl[(i,j)][A[k][l]],(-d,(k,l)))
    # 文字:[座標]の辞書
    char2ij = defaultdict(list)
    for i in range(N):
        for j in range(N):
            char2ij[A[i][j]].append((i,j))
    # t[i][0]は全ての座標，t[i][j]はt[i][j-1]から近い座標5個まで記録して，各t[i][0]から始めた時のt[i][4]までの最短距離と座標を記録
    # tのi番目の文字列は(j,k)から始めた時，距離lで，(m,n)に行ける，i番目:t[i][0]の座標:(距離,t[i][4]までの座標)
    ti2jk2dlm = defaultdict(lambda:defaultdict(lambda:(1000,[])))
    for i in range(M):
        for k,l in char2ij[t[i][0]]:
            # q: j文字目, 総距離d, [(k,l)]座標
            q = deque([(0,0,[(k,l)])])
            while q:
                j,d,mnlist = q.popleft()
                m,n = mnlist[-1]
                for d_,(o,p) in ij2char2dkl[(m,n)][t[i][j+1]]:
                    d_ = -d_
                    if j+1 == len(t[i])-1:
                        if d+d_ < ti2jk2dlm[i][(k,l)][0]:
                            ti2jk2dlm[i][(k,l)] = (d+d_,mnlist+[(o,p)])
                    else:
                        q.append((j+1,d+d_,mnlist+[(o,p)]))
    # これで各tについて，t[i][0]の文字の座標から始めた時のt[i][4]の座標までの短い距離と座標がわかる
    # -----------------あとで改善する(Mの順番)-----------------
    # 今の座標からt[i][0]までの距離とt[i][0]からt[i][4]までの距離を足したものが最小になるiと座標を選ぶ
    nowi,nowj = si,sj
    print(nowi,nowj)
    out.append(A[nowi][nowj])
    seen = set()
    for j in range(M):
        min_j = -1
        min_d_ = 1000
        min_ij_list_ = []
        for i in range(M):
            if i in seen:
                continue
            # 今の座標からt[i][0]までの距離とt[i][0]からt[i][4]までの距離を足したものが最小になる座標を選ぶ
            ti0 = t[i][0]
            min_d = 1000
            min_ij_list = []
            for k,l in char2ij[ti0]:
                if ti2jk2dlm[i][(k,l)][0] + abs(nowi-k) + abs(nowj-l) < min_d:
                    min_d = ti2jk2dlm[i][(k,l)][0] + abs(nowi-k) + abs(nowj-l)
                    min_ij_list = ti2jk2dlm[i][(k,l)][1]
            if min_d < min_d_:
                min_d_ = min_d
                min_ij_list_ = min_ij_list
                min_j = i
        # 最後n文字と最初n文字が同じなら省略
        # min_ij_listを文字に変換
        min_ij_A = []
        for k,l in min_ij_list_:
            min_ij_A.append(A[k][l])
        tmp = min(len(out),len(min_ij_A))
        # outの最後n文字とklの最初n文字が同じなら，klの最初n文字を省略
        while tmp > 0 and out[-tmp:] != min_ij_A[:tmp]:
            tmp -= 1
        for i,kl in enumerate(min_ij_list_):
            if i < tmp:
                continue
            print(*kl)
            out.append(A[kl[0]][kl[1]])
        nowi,nowj = min_ij_list_[-1]
        seen.add(min_j)

if __name__ == "__main__":
    main()

# %%
from heapq import *
from collections import deque
from collections import defaultdict

def main():
    # N,M = 15,200
    out = []
    N,M = map(int,input().split())
    si,sj = map(int,input().split())
    A = [list(input()) for _ in range(N)]
    t = [input() for _ in range(M)]
    # -----------------あとで改善する(上位5座標)-----------------
    # 各座標から各文字までの距離が短い順に上位5座標，座標:文字:[(距離,座標)] (heapで最大値を管理して，5個以上の時はpopする)
    ij2char2dkl = defaultdict(lambda:defaultdict(list))
    for i in range(N):
        for j in range(N):
            for k in range(N):
                for l in range(N):
                    d = abs(i-k) + abs(j-l)
                    if len(ij2char2dkl[(i,j)][A[k][l]]) < 5:
                        heappush(ij2char2dkl[(i,j)][A[k][l]],(-d,(k,l)))
                    else:
                        heappushpop(ij2char2dkl[(i,j)][A[k][l]],(-d,(k,l)))
    # 文字:[座標]の辞書
    char2ij = defaultdict(list)
    for i in range(N):
        for j in range(N):
            char2ij[A[i][j]].append((i,j))
    # t[i][0]は全ての座標，t[i][j]はt[i][j-1]から近い座標5個まで記録して，各t[i][0]から始めた時のt[i][4]までの最短距離と座標を記録
    # tのi番目の文字列は(j,k)から始めた時，距離lで，(m,n)に行ける，i番目:t[i][0]の座標:(距離,t[i][4]までの座標)
    ti2jk2dlm = defaultdict(lambda:defaultdict(lambda:(1000,[])))
    for i in range(M):
        for k,l in char2ij[t[i][0]]:
            # q: j文字目, 総距離d, [(k,l)]座標
            q = deque([(0,0,[(k,l)])])
            while q:
                j,d,mnlist = q.popleft()
                m,n = mnlist[-1]
                for d_,(o,p) in ij2char2dkl[(m,n)][t[i][j+1]]:
                    d_ = -d_
                    if j+1 == len(t[i])-1:
                        if d+d_ < ti2jk2dlm[i][(k,l)][0]:
                            ti2jk2dlm[i][(k,l)] = (d+d_,mnlist+[(o,p)])
                    else:
                        q.append((j+1,d+d_,mnlist+[(o,p)]))
    # これで各tについて，t[i][0]の文字の座標から始めた時のt[i][4]の座標までの短い距離と座標がわかる
    # -----------------あとで改善する(Mの順番)-----------------
    # 今の座標からt[i][0]までの距離とt[i][0]からt[i][4]までの距離を足したものが最小になるiと座標を選ぶ
    nowi,nowj = si,sj
    print(nowi,nowj)
    out.append(A[nowi][nowj])
    seen = set()
    for j in range(M):
        min_j = -1
        min_d_ = 1000
        min_ij_list_ = []
        for i in range(M):
            if i in seen:
                continue
            # 今の座標からt[i][0]までの距離とt[i][0]からt[i][4]までの距離を足したものが最小になる座標を選ぶ
            # 距離の計算にも最後n文字と最初n文字が同じなら有利にする
            ti0 = t[i][0]
            min_d = 1000
            min_ij_list = []
            for k,l in char2ij[ti0]:
                d = ti2jk2dlm[i][(k,l)][0] + abs(nowi-k) + abs(nowj-l)
                ij_list = ti2jk2dlm[i][(k,l)][1]
                # 最後n文字と最初n文字が同じならその分距離を短くする
                # ij_listを文字に変換
                ij_A = []
                for m,n in ij_list:
                    ij_A.append(A[m][n])
                tmp = min(len(out),len(ij_A))
                # outの最後n文字とtmpの最初n文字が同じなら，tmpの最初n文字の距離を短くする
                while tmp > 0 and out[-tmp:] != ij_A[:tmp]:
                    tmp -= 1
                if tmp > 0:
                    new_list = ij_list[tmp:]
                    new_dist = 0
                    nowi_,nowj_ = nowi,nowj
                    for m,n in new_list:
                        new_dist += abs(nowi_-m) + abs(nowj_-n)
                        nowi_,nowj_ = m,n
                    d = new_dist
                if d < min_d:
                    min_d = d
                    min_ij_list = ij_list
            if min_d < min_d_:
                min_d_ = min_d
                min_ij_list_ = min_ij_list
                min_j = i
        # 最後n文字と最初n文字が同じなら省略
        # min_ij_listを文字に変換
        min_ij_A = []
        for k,l in min_ij_list_:
            min_ij_A.append(A[k][l])
        tmp = min(len(out),len(min_ij_A))
        # outの最後n文字とklの最初n文字が同じなら，klの最初n文字を省略
        while tmp > 0 and out[-tmp:] != min_ij_A[:tmp]:
            tmp -= 1
        for i,kl in enumerate(min_ij_list_):
            if i < tmp:
                continue
            print(*kl)
            out.append(A[kl[0]][kl[1]])
        nowi,nowj = min_ij_list_[-1]
        seen.add(min_j)

if __name__ == "__main__":
    main()

# %%
# 上位3座標

from heapq import *
from collections import deque
from collections import defaultdict

def main():
    # N,M = 15,200
    out = []
    N,M = map(int,input().split())
    si,sj = map(int,input().split())
    A = [list(input()) for _ in range(N)]
    t = [input() for _ in range(M)]
    # -----------------あとで改善する(上位r座標)-----------------
    # 各座標から各文字までの距離が短い順に上位r座標，座標:文字:[(距離,座標)] (heapで最大値を管理して，5個以上の時はpopする)
    r = 3
    ij2char2dkl = defaultdict(lambda:defaultdict(list))
    for i in range(N):
        for j in range(N):
            for k in range(N):
                for l in range(N):
                    d = abs(i-k) + abs(j-l)
                    if len(ij2char2dkl[(i,j)][A[k][l]]) < r:
                        heappush(ij2char2dkl[(i,j)][A[k][l]],(-d,(k,l)))
                    else:
                        heappushpop(ij2char2dkl[(i,j)][A[k][l]],(-d,(k,l)))
    # 文字:[座標]の辞書
    char2ij = defaultdict(list)
    for i in range(N):
        for j in range(N):
            char2ij[A[i][j]].append((i,j))
    # t[i][0]は全ての座標，t[i][j]はt[i][j-1]から近い座標5個まで記録して，各t[i][0]から始めた時のt[i][4]までの最短距離と座標を記録
    # tのi番目の文字列は(j,k)から始めた時，距離lで，(m,n)に行ける，i番目:t[i][0]の座標:(距離,t[i][4]までの座標)
    ti2jk2dlm = defaultdict(lambda:defaultdict(lambda:(1000,[])))
    for i in range(M):
        for k,l in char2ij[t[i][0]]:
            # q: j文字目, 総距離d, [(k,l)]座標
            q = deque([(0,0,[(k,l)])])
            while q:
                j,d,mnlist = q.popleft()
                m,n = mnlist[-1]
                for d_,(o,p) in ij2char2dkl[(m,n)][t[i][j+1]]:
                    d_ = -d_
                    if j+1 == len(t[i])-1:
                        if d+d_ < ti2jk2dlm[i][(k,l)][0]:
                            ti2jk2dlm[i][(k,l)] = (d+d_,mnlist+[(o,p)])
                    else:
                        q.append((j+1,d+d_,mnlist+[(o,p)]))
    # これで各tについて，t[i][0]の文字の座標から始めた時のt[i][4]の座標までの短い距離と座標がわかる
    # -----------------あとで改善する(Mの順番)-----------------
    # 今の座標からt[i][0]までの距離とt[i][0]からt[i][4]までの距離を足したものが最小になるiと座標を選ぶ
    nowi,nowj = si,sj
    print(nowi,nowj)
    out.append(A[nowi][nowj])
    seen = set()
    for j in range(M):
        min_j = -1
        min_d_ = 1000
        min_ij_list_ = []
        for i in range(M):
            if i in seen:
                continue
            # 今の座標からt[i][0]までの距離とt[i][0]からt[i][4]までの距離を足したものが最小になる座標を選ぶ
            # 距離の計算にも最後n文字と最初n文字が同じなら有利にする
            ti0 = t[i][0]
            min_d = 1000
            min_ij_list = []
            for k,l in char2ij[ti0]:
                d = ti2jk2dlm[i][(k,l)][0] + abs(nowi-k) + abs(nowj-l)
                ij_list = ti2jk2dlm[i][(k,l)][1]
                # 最後n文字と最初n文字が同じならその分距離を短くする
                # ij_listを文字に変換
                ij_A = []
                for m,n in ij_list:
                    ij_A.append(A[m][n])
                tmp = min(len(out),len(ij_A))
                # outの最後n文字とtmpの最初n文字が同じなら，tmpの最初n文字の距離を短くする
                while tmp > 0 and out[-tmp:] != ij_A[:tmp]:
                    tmp -= 1
                if tmp > 0:
                    new_list = ij_list[tmp:]
                    new_dist = 0
                    nowi_,nowj_ = nowi,nowj
                    for m,n in new_list:
                        new_dist += abs(nowi_-m) + abs(nowj_-n)
                        nowi_,nowj_ = m,n
                    d = new_dist
                if d < min_d:
                    min_d = d
                    min_ij_list = ij_list
            if min_d < min_d_:
                min_d_ = min_d
                min_ij_list_ = min_ij_list
                min_j = i
        # 最後n文字と最初n文字が同じなら省略
        # min_ij_listを文字に変換
        min_ij_A = []
        for k,l in min_ij_list_:
            min_ij_A.append(A[k][l])
        tmp = min(len(out),len(min_ij_A))
        # outの最後n文字とklの最初n文字が同じなら，klの最初n文字を省略
        while tmp > 0 and out[-tmp:] != min_ij_A[:tmp]:
            tmp -= 1
        for i,kl in enumerate(min_ij_list_):
            if i < tmp:
                continue
            print(*kl)
            out.append(A[kl[0]][kl[1]])
        nowi,nowj = min_ij_list_[-1]
        seen.add(min_j)

if __name__ == "__main__":
    main()

# %%
# 上位7座標

from heapq import *
from collections import deque
from collections import defaultdict

def main():
    # N,M = 15,200
    out = []
    N,M = map(int,input().split())
    si,sj = map(int,input().split())
    A = [list(input()) for _ in range(N)]
    t = [input() for _ in range(M)]
    # -----------------あとで改善する(上位r座標)-----------------
    # 各座標から各文字までの距離が短い順に上位r座標，座標:文字:[(距離,座標)] (heapで最大値を管理して，5個以上の時はpopする)
    r = 7
    ij2char2dkl = defaultdict(lambda:defaultdict(list))
    for i in range(N):
        for j in range(N):
            for k in range(N):
                for l in range(N):
                    d = abs(i-k) + abs(j-l)
                    if len(ij2char2dkl[(i,j)][A[k][l]]) < r:
                        heappush(ij2char2dkl[(i,j)][A[k][l]],(-d,(k,l)))
                    else:
                        heappushpop(ij2char2dkl[(i,j)][A[k][l]],(-d,(k,l)))
    # 文字:[座標]の辞書
    char2ij = defaultdict(list)
    for i in range(N):
        for j in range(N):
            char2ij[A[i][j]].append((i,j))
    # t[i][0]は全ての座標，t[i][j]はt[i][j-1]から近い座標5個まで記録して，各t[i][0]から始めた時のt[i][4]までの最短距離と座標を記録
    # tのi番目の文字列は(j,k)から始めた時，距離lで，(m,n)に行ける，i番目:t[i][0]の座標:(距離,t[i][4]までの座標)
    ti2jk2dlm = defaultdict(lambda:defaultdict(lambda:(1000,[])))
    for i in range(M):
        for k,l in char2ij[t[i][0]]:
            # q: j文字目, 総距離d, [(k,l)]座標
            q = deque([(0,0,[(k,l)])])
            while q:
                j,d,mnlist = q.popleft()
                m,n = mnlist[-1]
                for d_,(o,p) in ij2char2dkl[(m,n)][t[i][j+1]]:
                    d_ = -d_
                    if j+1 == len(t[i])-1:
                        if d+d_ < ti2jk2dlm[i][(k,l)][0]:
                            ti2jk2dlm[i][(k,l)] = (d+d_,mnlist+[(o,p)])
                    else:
                        q.append((j+1,d+d_,mnlist+[(o,p)]))
    # これで各tについて，t[i][0]の文字の座標から始めた時のt[i][4]の座標までの短い距離と座標がわかる
    # -----------------あとで改善する(Mの順番)-----------------
    # 今の座標からt[i][0]までの距離とt[i][0]からt[i][4]までの距離を足したものが最小になるiと座標を選ぶ
    nowi,nowj = si,sj
    print(nowi,nowj)
    out.append(A[nowi][nowj])
    seen = set()
    for j in range(M):
        min_j = -1
        min_d_ = 1000
        min_ij_list_ = []
        for i in range(M):
            if i in seen:
                continue
            # 今の座標からt[i][0]までの距離とt[i][0]からt[i][4]までの距離を足したものが最小になる座標を選ぶ
            # 距離の計算にも最後n文字と最初n文字が同じなら有利にする
            ti0 = t[i][0]
            min_d = 1000
            min_ij_list = []
            for k,l in char2ij[ti0]:
                d = ti2jk2dlm[i][(k,l)][0] + abs(nowi-k) + abs(nowj-l)
                ij_list = ti2jk2dlm[i][(k,l)][1]
                # 最後n文字と最初n文字が同じならその分距離を短くする
                # ij_listを文字に変換
                ij_A = []
                for m,n in ij_list:
                    ij_A.append(A[m][n])
                tmp = min(len(out),len(ij_A))
                # outの最後n文字とtmpの最初n文字が同じなら，tmpの最初n文字の距離を短くする
                while tmp > 0 and out[-tmp:] != ij_A[:tmp]:
                    tmp -= 1
                if tmp > 0:
                    new_list = ij_list[tmp:]
                    new_dist = 0
                    nowi_,nowj_ = nowi,nowj
                    for m,n in new_list:
                        new_dist += abs(nowi_-m) + abs(nowj_-n)
                        nowi_,nowj_ = m,n
                    d = new_dist
                if d < min_d:
                    min_d = d
                    min_ij_list = ij_list
            if min_d < min_d_:
                min_d_ = min_d
                min_ij_list_ = min_ij_list
                min_j = i
        # 最後n文字と最初n文字が同じなら省略
        # min_ij_listを文字に変換
        min_ij_A = []
        for k,l in min_ij_list_:
            min_ij_A.append(A[k][l])
        tmp = min(len(out),len(min_ij_A))
        # outの最後n文字とklの最初n文字が同じなら，klの最初n文字を省略
        while tmp > 0 and out[-tmp:] != min_ij_A[:tmp]:
            tmp -= 1
        for i,kl in enumerate(min_ij_list_):
            if i < tmp:
                continue
            print(*kl)
            out.append(A[kl[0]][kl[1]])
        nowi,nowj = min_ij_list_[-1]
        seen.add(min_j)

if __name__ == "__main__":
    main()

# %%
# 上位10座標

from heapq import *
from collections import deque
from collections import defaultdict

def main():
    # N,M = 15,200
    out = []
    N,M = map(int,input().split())
    si,sj = map(int,input().split())
    A = [list(input()) for _ in range(N)]
    t = [input() for _ in range(M)]
    # -----------------あとで改善する(上位r座標)-----------------
    # 各座標から各文字までの距離が短い順に上位r座標，座標:文字:[(距離,座標)] (heapで最大値を管理して，5個以上の時はpopする)
    r = 10
    ij2char2dkl = defaultdict(lambda:defaultdict(list))
    for i in range(N):
        for j in range(N):
            for k in range(N):
                for l in range(N):
                    d = abs(i-k) + abs(j-l)
                    if len(ij2char2dkl[(i,j)][A[k][l]]) < r:
                        heappush(ij2char2dkl[(i,j)][A[k][l]],(-d,(k,l)))
                    else:
                        heappushpop(ij2char2dkl[(i,j)][A[k][l]],(-d,(k,l)))
    # 文字:[座標]の辞書
    char2ij = defaultdict(list)
    for i in range(N):
        for j in range(N):
            char2ij[A[i][j]].append((i,j))
    # t[i][0]は全ての座標，t[i][j]はt[i][j-1]から近い座標5個まで記録して，各t[i][0]から始めた時のt[i][4]までの最短距離と座標を記録
    # tのi番目の文字列は(j,k)から始めた時，距離lで，(m,n)に行ける，i番目:t[i][0]の座標:(距離,t[i][4]までの座標)
    ti2jk2dlm = defaultdict(lambda:defaultdict(lambda:(1000,[])))
    for i in range(M):
        for k,l in char2ij[t[i][0]]:
            # q: j文字目, 総距離d, [(k,l)]座標
            q = deque([(0,0,[(k,l)])])
            while q:
                j,d,mnlist = q.popleft()
                m,n = mnlist[-1]
                for d_,(o,p) in ij2char2dkl[(m,n)][t[i][j+1]]:
                    d_ = -d_
                    if j+1 == len(t[i])-1:
                        if d+d_ < ti2jk2dlm[i][(k,l)][0]:
                            ti2jk2dlm[i][(k,l)] = (d+d_,mnlist+[(o,p)])
                    else:
                        q.append((j+1,d+d_,mnlist+[(o,p)]))
    # これで各tについて，t[i][0]の文字の座標から始めた時のt[i][4]の座標までの短い距離と座標がわかる
    # -----------------あとで改善する(Mの順番)-----------------
    # 今の座標からt[i][0]までの距離とt[i][0]からt[i][4]までの距離を足したものが最小になるiと座標を選ぶ
    nowi,nowj = si,sj
    print(nowi,nowj)
    out.append(A[nowi][nowj])
    seen = set()
    for j in range(M):
        min_j = -1
        min_d_ = 1000
        min_ij_list_ = []
        for i in range(M):
            if i in seen:
                continue
            # 今の座標からt[i][0]までの距離とt[i][0]からt[i][4]までの距離を足したものが最小になる座標を選ぶ
            # 距離の計算にも最後n文字と最初n文字が同じなら有利にする
            ti0 = t[i][0]
            min_d = 1000
            min_ij_list = []
            for k,l in char2ij[ti0]:
                d = ti2jk2dlm[i][(k,l)][0] + abs(nowi-k) + abs(nowj-l)
                ij_list = ti2jk2dlm[i][(k,l)][1]
                # 最後n文字と最初n文字が同じならその分距離を短くする
                # ij_listを文字に変換
                ij_A = []
                for m,n in ij_list:
                    ij_A.append(A[m][n])
                tmp = min(len(out),len(ij_A))
                # outの最後n文字とtmpの最初n文字が同じなら，tmpの最初n文字の距離を短くする
                while tmp > 0 and out[-tmp:] != ij_A[:tmp]:
                    tmp -= 1
                if tmp > 0:
                    new_list = ij_list[tmp:]
                    new_dist = 0
                    nowi_,nowj_ = nowi,nowj
                    for m,n in new_list:
                        new_dist += abs(nowi_-m) + abs(nowj_-n)
                        nowi_,nowj_ = m,n
                    d = new_dist
                if d < min_d:
                    min_d = d
                    min_ij_list = ij_list
            if min_d < min_d_:
                min_d_ = min_d
                min_ij_list_ = min_ij_list
                min_j = i
        # 最後n文字と最初n文字が同じなら省略
        # min_ij_listを文字に変換
        min_ij_A = []
        for k,l in min_ij_list_:
            min_ij_A.append(A[k][l])
        tmp = min(len(out),len(min_ij_A))
        # outの最後n文字とklの最初n文字が同じなら，klの最初n文字を省略
        while tmp > 0 and out[-tmp:] != min_ij_A[:tmp]:
            tmp -= 1
        for i,kl in enumerate(min_ij_list_):
            if i < tmp:
                continue
            print(*kl)
            out.append(A[kl[0]][kl[1]])
        nowi,nowj = min_ij_list_[-1]
        seen.add(min_j)

if __name__ == "__main__":
    main()

# %%
# 全座標

from heapq import *
from collections import deque
from collections import defaultdict

def main():
    # N,M = 15,200
    out = []
    N,M = map(int,input().split())
    si,sj = map(int,input().split())
    A = [list(input()) for _ in range(N)]
    t = [input() for _ in range(M)]
    # -----------------あとで改善する(上位r座標)-----------------
    # 各座標から各文字までの距離が短い順に上位r座標，座標:文字:[(距離,座標)] (heapで最大値を管理して，5個以上の時はpopする)
    r = 1000
    ij2char2dkl = defaultdict(lambda:defaultdict(list))
    for i in range(N):
        for j in range(N):
            for k in range(N):
                for l in range(N):
                    d = abs(i-k) + abs(j-l)
                    if len(ij2char2dkl[(i,j)][A[k][l]]) < r:
                        heappush(ij2char2dkl[(i,j)][A[k][l]],(-d,(k,l)))
                    else:
                        heappushpop(ij2char2dkl[(i,j)][A[k][l]],(-d,(k,l)))
    # 文字:[座標]の辞書
    char2ij = defaultdict(list)
    for i in range(N):
        for j in range(N):
            char2ij[A[i][j]].append((i,j))
    # t[i][0]は全ての座標，t[i][j]はt[i][j-1]から近い座標5個まで記録して，各t[i][0]から始めた時のt[i][4]までの最短距離と座標を記録
    # tのi番目の文字列は(j,k)から始めた時，距離lで，(m,n)に行ける，i番目:t[i][0]の座標:(距離,t[i][4]までの座標)
    ti2jk2dlm = defaultdict(lambda:defaultdict(lambda:(1000,[])))
    for i in range(M):
        for k,l in char2ij[t[i][0]]:
            # q: j文字目, 総距離d, [(k,l)]座標
            q = deque([(0,0,[(k,l)])])
            while q:
                j,d,mnlist = q.popleft()
                m,n = mnlist[-1]
                for d_,(o,p) in ij2char2dkl[(m,n)][t[i][j+1]]:
                    d_ = -d_
                    if j+1 == len(t[i])-1:
                        if d+d_ < ti2jk2dlm[i][(k,l)][0]:
                            ti2jk2dlm[i][(k,l)] = (d+d_,mnlist+[(o,p)])
                    else:
                        q.append((j+1,d+d_,mnlist+[(o,p)]))
    # これで各tについて，t[i][0]の文字の座標から始めた時のt[i][4]の座標までの短い距離と座標がわかる
    # -----------------あとで改善する(Mの順番)-----------------
    # 今の座標からt[i][0]までの距離とt[i][0]からt[i][4]までの距離を足したものが最小になるiと座標を選ぶ
    nowi,nowj = si,sj
    print(nowi,nowj)
    out.append(A[nowi][nowj])
    seen = set()
    for j in range(M):
        min_j = -1
        min_d_ = 1000
        min_ij_list_ = []
        for i in range(M):
            if i in seen:
                continue
            # 今の座標からt[i][0]までの距離とt[i][0]からt[i][4]までの距離を足したものが最小になる座標を選ぶ
            # 距離の計算にも最後n文字と最初n文字が同じなら有利にする
            ti0 = t[i][0]
            min_d = 1000
            min_ij_list = []
            for k,l in char2ij[ti0]:
                d = ti2jk2dlm[i][(k,l)][0] + abs(nowi-k) + abs(nowj-l)
                ij_list = ti2jk2dlm[i][(k,l)][1]
                # 最後n文字と最初n文字が同じならその分距離を短くする
                # ij_listを文字に変換
                ij_A = []
                for m,n in ij_list:
                    ij_A.append(A[m][n])
                tmp = min(len(out),len(ij_A))
                # outの最後n文字とtmpの最初n文字が同じなら，tmpの最初n文字の距離を短くする
                while tmp > 0 and out[-tmp:] != ij_A[:tmp]:
                    tmp -= 1
                if tmp > 0:
                    new_list = ij_list[tmp:]
                    new_dist = 0
                    nowi_,nowj_ = nowi,nowj
                    for m,n in new_list:
                        new_dist += abs(nowi_-m) + abs(nowj_-n)
                        nowi_,nowj_ = m,n
                    d = new_dist
                if d < min_d:
                    min_d = d
                    min_ij_list = ij_list
            if min_d < min_d_:
                min_d_ = min_d
                min_ij_list_ = min_ij_list
                min_j = i
        # 最後n文字と最初n文字が同じなら省略
        # min_ij_listを文字に変換
        min_ij_A = []
        for k,l in min_ij_list_:
            min_ij_A.append(A[k][l])
        tmp = min(len(out),len(min_ij_A))
        # outの最後n文字とklの最初n文字が同じなら，klの最初n文字を省略
        while tmp > 0 and out[-tmp:] != min_ij_A[:tmp]:
            tmp -= 1
        for i,kl in enumerate(min_ij_list_):
            if i < tmp:
                continue
            print(*kl)
            out.append(A[kl[0]][kl[1]])
        nowi,nowj = min_ij_list_[-1]
        seen.add(min_j)

if __name__ == "__main__":
    main()

# %%
from heapq import *
from collections import deque
from collections import defaultdict

def main():
    # N,M = 15,200
    out = []
    N,M = map(int,input().split())
    si,sj = map(int,input().split())
    A = [list(input()) for _ in range(N)]
    t = [input() for _ in range(M)]
    # -----------------あとで改善する(上位5座標)-----------------
    # 各座標から各文字までの距離が短い順に上位5座標，座標:文字:[(距離,座標)] (heapで最大値を管理して，5個以上の時はpopする)
    ij2char2dkl = defaultdict(lambda:defaultdict(list))
    for i in range(N):
        for j in range(N):
            for k in range(N):
                for l in range(N):
                    d = abs(i-k) + abs(j-l)
                    if len(ij2char2dkl[(i,j)][A[k][l]]) < 5:
                        heappush(ij2char2dkl[(i,j)][A[k][l]],(-d,(k,l)))
                    else:
                        heappushpop(ij2char2dkl[(i,j)][A[k][l]],(-d,(k,l)))
    # 文字:[座標]の辞書
    char2ij = defaultdict(list)
    for i in range(N):
        for j in range(N):
            char2ij[A[i][j]].append((i,j))
    # t[i][0]は全ての座標，t[i][j]はt[i][j-1]から近い座標5個まで記録して，各t[i][0]から始めた時のt[i][4]までの最短距離と座標を記録
    # tのi番目の文字列は(j,k)から始めた時，距離lで，(m,n)に行ける，i番目:t[i][0]の座標:(距離,t[i][4]までの座標)
    ti2jk2dlm = defaultdict(lambda:defaultdict(lambda:(1000,[])))
    for i in range(M):
        for k,l in char2ij[t[i][0]]:
            # q: j文字目, 総距離d, [(k,l)]座標
            q = deque([(0,0,[(k,l)])])
            while q:
                j,d,mnlist = q.popleft()
                m,n = mnlist[-1]
                for d_,(o,p) in ij2char2dkl[(m,n)][t[i][j+1]]:
                    d_ = -d_
                    if j+1 == len(t[i])-1:
                        if d+d_ < ti2jk2dlm[i][(k,l)][0]:
                            ti2jk2dlm[i][(k,l)] = (d+d_,mnlist+[(o,p)])
                    else:
                        q.append((j+1,d+d_,mnlist+[(o,p)]))
    # これで各tについて，t[i][0]の文字の座標から始めた時のt[i][4]の座標までの短い距離と座標がわかる
    # -----------------あとで改善する(Mの順番)-----------------
    # 今の座標からt[i][0]までの距離とt[i][0]からt[i][4]までの距離を足したものが最小になるiと座標を選ぶ
    nowi,nowj = si,sj
    print(nowi,nowj)
    out.append(A[nowi][nowj])
    seen = set()
    for j in range(M):
        min_j = -1
        min_d_ = 1000
        min_ij_list_ = []
        for i in range(M):
            if i in seen:
                continue
            # 今の座標からt[i][0]までの距離とt[i][0]からt[i][4]までの距離を足したものが最小になる座標を選ぶ
            # 距離の計算にも最後n文字と最初n文字が同じなら有利にする
            ti0 = t[i][0]
            min_d = 1000
            min_ij_list = []
            for k,l in char2ij[ti0]:
                d = ti2jk2dlm[i][(k,l)][0] + abs(nowi-k) + abs(nowj-l)
                ij_list = ti2jk2dlm[i][(k,l)][1]
                # 最後n文字と最初n文字が同じならその分距離を短くする
                # ij_listを文字に変換
                ij_A = []
                for m,n in ij_list:
                    ij_A.append(A[m][n])
                tmp = min(len(out),len(ij_A))
                # outの最後n文字とtmpの最初n文字が同じなら，tmpの最初n文字の距離を短くする
                while tmp > 0 and out[-tmp:] != ij_A[:tmp]:
                    tmp -= 1
                if tmp > 0:
                    new_list = ij_list[tmp:]
                    new_dist = 0
                    nowi_,nowj_ = nowi,nowj
                    for m,n in new_list:
                        new_dist += abs(nowi_-m) + abs(nowj_-n)
                        nowi_,nowj_ = m,n
                    d = new_dist
                if d < min_d:
                    min_d = d
                    min_ij_list = ij_list
            if min_d < min_d_:
                min_d_ = min_d
                min_ij_list_ = min_ij_list
                min_j = i
        # 最後n文字と最初n文字が同じなら省略
        # min_ij_listを文字に変換
        min_ij_A = []
        for k,l in min_ij_list_:
            min_ij_A.append(A[k][l])
        tmp = min(len(out),len(min_ij_A))
        # outの最後n文字とklの最初n文字が同じなら，klの最初n文字を省略
        while tmp > 0 and out[-tmp:] != min_ij_A[:tmp]:
            tmp -= 1
        for i,kl in enumerate(min_ij_list_):
            if i < tmp:
                continue
            print(*kl)
            out.append(A[kl[0]][kl[1]])
        nowi,nowj = min_ij_list_[-1]
        seen.add(min_j)

if __name__ == "__main__":
    main()
