# %%
from functools import lru_cache
import sys
sys.setrecursionlimit(10**9)
# input = sys.stdin.readline
from decimal import Decimal
from functools import cmp_to_key
from collections import Counter
from itertools import permutations
from itertools import combinations
from itertools import combinations_with_replacement
from copy import deepcopy
import math
import heapq
from collections import OrderedDict
import bisect
from collections import defaultdict

from collections import deque

def main():
    D,N = map(int,input().split())
    # 空きマスの数
    space = 81-N
    # -2が空きマス，-1が壁，0以上はコンテナ番号
    souko = [[-1]*11] + [[-1] + [-2]*9 + [-1] for _ in [0]*9] + [[-1]*11]
    # 各コンテナを格納したい場所の候補
    # hope = {0:[(0,3),(1,4),(0,5)],1:[(0,3),(1,4),(0,5)],2:[(0,3),(1,4),(0,5)],
    #         3:[(0,2),(1,3),(2,4),(1,5),(0,6)],4:[(0,2),(1,3),(2,4),(1,5),(0,6)],5:[(0,2),(1,3),(2,4),(1,5),(0,6)],6:[(0,2),(1,3),(2,4),(1,5),(0,6)],7:[(0,2),(1,3),(2,4),(1,5),(0,6)],
    #         8:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],9:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],10:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],11:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],12:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],13:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],14:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],
    #         15:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],16:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],17:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],18:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],19:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],20:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],21:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],22:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],23:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],
    #         24:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],25:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],26:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],27:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],28:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],29:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],30:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],31:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],32:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],
    #         33:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],34:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],35:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],36:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],37:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],38:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],39:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],40:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],41:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],
    #         42:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],43:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],44:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],45:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],46:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],47:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],48:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],49:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],50:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],
    #         51:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],52:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],53:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],54:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],55:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],56:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],57:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],58:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],59:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],
    #         60:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],61:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],62:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],63:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],64:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],65:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],66:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],67:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],
    #         68:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],69:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],70:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],71:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],72:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],73:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],
    #         74:[(7,0),(8,1),(8,7),(7,8)],75:[(7,0),(8,1),(8,7),(7,8)],76:[(7,0),(8,1),(8,7),(7,8)],77:[(7,0),(8,1),(8,7),(7,8)],
    #         78:[(8,0),(8,8)],79:[(8,0),(8,8)]
    #         }
    # hope = {0:[(0,3),(0,5),(1,4)],1:[(0,3),(0,5),(1,4)],2:[(0,3),(0,5),(1,4)],
    #         3:[(0,6),(1,5),(0,2),(1,3),(2,4)],4:[(0,6),(1,5),(0,2),(1,3),(2,4)],5:[(0,6),(1,5),(0,2),(1,3),(2,4)],6:[(0,6),(1,5),(0,2),(1,3),(2,4)],7:[(0,6),(1,5),(0,2),(1,3),(2,4)],
    #         8:[(0,1),(1,2),(2,3),(0,7),(1,6),(2,5),(3,4)],9:[(0,1),(1,2),(2,3),(0,7),(1,6),(2,5),(3,4)],10:[(0,1),(1,2),(2,3),(0,7),(1,6),(2,5),(3,4)],11:[(0,1),(1,2),(2,3),(0,7),(1,6),(2,5),(3,4)],12:[(0,1),(1,2),(2,3),(0,7),(1,6),(2,5),(3,4)],13:[(0,1),(1,2),(2,3),(0,7),(1,6),(2,5),(3,4)],14:[(0,1),(1,2),(2,3),(0,7),(1,6),(2,5),(3,4)],
        16:[(2,2),(2,6)],17:[(2,2),(2,6)],
        18:[(2,1),(2,7)],19:[(2,1),(2,7)],
        20:[(2,0),(2,8)],21:[(2,0),(2,8)],
        22:[(3,3),(3,5)],23:[(3,3),(3,5)],
        24:[(4,3),(5,4),(4,5)],25:[(4,3),(5,4),(4,5)],26:[(4,3),(5,4),(4,5)],
        27:[(4,2),(6,4),(4,6)],28:[(4,2),(6,4),(4,6)],29:[(4,2),(6,4),(4,6)],
        30:[(4,1),(7,4),(4,7)],31:[(4,1),(7,4),(4,7)],32:[(4,1),(7,4),(4,7)],
        33:[(4,0),(8,4),(4,8)],34:[(4,0),(8,4),(4,8)],35:[(4,0),(8,4),(4,8)],
        36:[(5,3),(5,5)],37:[(5,3),(5,5)],
        38:[(6,3),(6,5)],39:[(6,3),(6,5)],
        40:[(6,2),(6,6)],41:[(6,2),(6,6)],
        42:[(6,1),(6,7)],43:[(6,1),(6,7)],
        44:[(6,0),(6,8)],45:[(6,0),(6,8)],
        46:[(7,3),(7,5)],47:[(7,3),(7,5)],
        48:[(8,3),(8,5)],49:[(8,3),(8,5)],
        50:[(8,2),(8,6)],51:[(8,2),(8,6)],
        52:[(8,1),(8,7)],53:[(8,1),(8,7)],
        54:[(8,0),(8,8)],55:[(8,0),(8,8)],
        56:[(1,2),(1,6)],57:[(1,2),(1,6)],
        58:[(1,1),(1,7)],59:[(1,1),(1,7)],
        60:[(1,0),(1,8)],61:[(1,0),(1,8)],
        62:[(3,2),(3,6)],63:[(3,2),(3,6)],
        64:[(3,1),(3,7)],65:[(3,1),(3,7)],
        66:[(3,0),(3,8)],67:[(3,0),(3,8)],
        68:[(5,2),(5,6)],69:[(5,2),(5,6)],
        70:[(5,1),(5,7)],71:[(5,1),(5,7)],
        72:[(5,0),(5,8)],73:[(5,0),(5,8)],
        74:[(7,2),(7,6)],75:[(7,2),(7,6)],
        76:[(7,1),(7,7)],77:[(7,1),(7,7)],
        78:[(7,0),(7,8)],79:[(7,0),(7,8)]
    }
    for _ in [0]*N:
        # 壁の座標
        ri,rj = map(int,input().split())
        souko[ri+1][rj+1] = -1
    for _ in [0]*(80-N):
        # 運び込まれるコンテナ番号
        con = int(input())
        # コンテナを格納したい場所の候補
        h_list = hope[con]
        # コンテナを格納したい場所の候補の中で，空いている場所を探す
        h_can_list = []
        for h in h_list:
            if souko[h[0]+1][h[1]+1] == -2:
                h_can_list.append(h)
        # 空いている場所にコンテナを格納した場合，入口(1,5)から到達できるマスの数が空きマスの数と同じならば，その場所にコンテナを格納する
        for h_can in h_can_list:
            # h_canにコンテナを格納した場合の倉庫の状態を作る
            souko[h_can[0]+1][h_can[1]+1] = con
            # 入口から到達できるマスの座標
            can_q = deque([(1,5)])
            # 到達したマスの集合
            can_set = set([(1,5)])
            # 入口から到達できるマスの座標を探索
            while can_q:
                i,j = can_q.pop()
                if souko[i][j] == -2:
                    # 上下左右のマスを探索
                    if souko[i-1][j] == -2 and (i-1,j) not in can_set:
                        can_q.append((i-1,j))
                        can_set.add((i-1,j))
                    if souko[i+1][j] == -2 and (i+1,j) not in can_set:
                        can_q.append((i+1,j))
                        can_set.add((i+1,j))
                    if souko[i][j-1] == -2 and (i,j-1) not in can_set:
                        can_q.append((i,j-1))
                        can_set.add((i,j-1))
                    if souko[i][j+1] == -2 and (i,j+1) not in can_set:
                        can_q.append((i,j+1))
                        can_set.add((i,j+1))
            if len(can_set) == space-1:
                # 入口から到達できるマスの数が空きマスの数と同じならば，その場所にコンテナを格納してあるから次のコンテナへ
                print(*h_can, flush=True)
                space -= 1
                break
            else:
                # 空きマスに戻す
                souko[h_can[0]+1][h_can[1]+1] = -2
        else:
            # コンテナを格納したい場所の候補の中で，コンテナを格納できる場所がない場合，一番奥に格納する(改善の余地あり，ほんまはできるだけ格納したい場所から近くに格納したい)
            # BFSで一番奥の空きマスを探索
            last_node = tuple()
            # 入口から到達できるマスの座標
            can_q = deque([(1,5)])
            # 到達したマスの集合
            can_set = set([(1,5)])
            # 入口から到達できるマスの座標を探索
            while can_q:
                i,j = can_q.popleft()
                if souko[i][j] == -2:
                    # 上下左右のマスを探索
                    if souko[i-1][j] == -2 and (i-1,j) not in can_set:
                        can_q.append((i-1,j))
                        can_set.add((i-1,j))
                    if souko[i+1][j] == -2 and (i+1,j) not in can_set:
                        can_q.append((i+1,j))
                        can_set.add((i+1,j))
                    if souko[i][j-1] == -2 and (i,j-1) not in can_set:
                        can_q.append((i,j-1))
                        can_set.add((i,j-1))
                    if souko[i][j+1] == -2 and (i,j+1) not in can_set:
                        can_q.append((i,j+1))
                        can_set.add((i,j+1))
                if len(can_q) == 0:
                    last_node = (i-1,j-1)
                    break
            # 一番奥の空きマスにコンテナを格納
            souko[last_node[0]+1][last_node[1]+1] = con
            print(*last_node, flush=True)
            space -= 1
    # 入口から到達できるコンテナのうち最小の番号のコンテナの座標を出力する
    for _ in [0]*80:
        # 到達できる最小のコンテナ番号とその座標
        min_con = 100
        min_node = tuple()
        # 入口(1,5)から到達できるコンテナの番号の座標を探索
        can_q = deque([(1,5)])
        # 到達したマスの集合
        can_set = set([(1,5)])
        # 入口から到達できるマスの座標を探索
        while can_q:
            i,j = can_q.pop()
            if souko[i][j] == -2:
                # 上下左右のマスを探索
                if souko[i-1][j] == -2 and (i-1,j) not in can_set:
                    can_q.append((i-1,j))
                    can_set.add((i-1,j))
                elif souko[i-1][j] >= 0 and souko[i-1][j] < min_con:
                    min_con = souko[i-1][j]
                    min_node = (i-1,j)
                if souko[i+1][j] == -2 and (i+1,j) not in can_set:
                    can_q.append((i+1,j))
                    can_set.add((i+1,j))
                elif souko[i+1][j] >= 0 and souko[i+1][j] < min_con:
                    min_con = souko[i+1][j]
                    min_node = (i+1,j)
                if souko[i][j-1] == -2 and (i,j-1) not in can_set:
                    can_q.append((i,j-1))
                    can_set.add((i,j-1))
                elif souko[i][j-1] >= 0 and souko[i][j-1] < min_con:
                    min_con = souko[i][j-1]
                    min_node = (i,j-1)
                if souko[i][j+1] == -2 and (i,j+1) not in can_set:
                    can_q.append((i,j+1))
                    can_set.add((i,j+1))
                elif souko[i][j+1] >= 0 and souko[i][j+1] < min_con:
                    min_con = souko[i][j+1]
                    min_node = (i,j+1)
        print(min_node[0]-1,min_node[1]-1, flush=True)
        souko[min_node[0]][min_node[1]] = -2
    
if __name__ == "__main__":
    main()
# Out:
# 80
# 81
# 0 0
# 79
# 80
# 0 2
# 78
# 79
# 1 3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 126
#     123         print(s)
#     125 if __name__ == "__main__":
# --> 126     main()
#
# Cell In[16], line 46, in main()
#      43     souko[ri+1][rj+1] = -1
#      44 for _ in [0]*(80-N):
#      45     # 運び込まれるコンテナ番号
# ---> 46     con = int(input())
#      47     # コンテナを格納したい場所の候補
#      48     h_list = hope[con]
#
# ValueError: invalid literal for int() with base 10: ''

# %%
from collections import deque

def main():
    D,N = map(int,input().split())
    # 空きマスの数
    space = 81-N
    # -2が空きマス，-1が壁，0以上はコンテナ番号
    souko = [[-1]*11] + [[-1] + [-2]*9 + [-1] for _ in [0]*9] + [[-1]*11]
    # 各コンテナを格納したい場所の候補
    # hope = {0:[(0,3),(1,4),(0,5)],1:[(0,3),(1,4),(0,5)],2:[(0,3),(1,4),(0,5)],
    #         3:[(0,2),(1,3),(2,4),(1,5),(0,6)],4:[(0,2),(1,3),(2,4),(1,5),(0,6)],5:[(0,2),(1,3),(2,4),(1,5),(0,6)],6:[(0,2),(1,3),(2,4),(1,5),(0,6)],7:[(0,2),(1,3),(2,4),(1,5),(0,6)],
    #         8:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],9:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],10:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],11:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],12:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],13:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],14:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],
    #         15:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],16:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],17:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],18:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],19:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],20:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],21:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],22:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],23:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],
    #         24:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],25:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],26:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],27:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],28:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],29:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],30:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],31:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],32:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],
    #         33:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],34:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],35:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],36:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],37:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],38:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],39:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],40:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],41:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],
    #         42:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],43:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],44:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],45:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],46:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],47:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],48:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],49:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],50:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],
    #         51:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],52:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],53:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],54:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],55:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],56:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],57:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],58:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],59:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],
    #         60:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],61:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],62:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],63:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],64:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],65:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],66:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],67:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],
    #         68:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],69:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],70:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],71:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],72:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],73:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],
    #         74:[(7,0),(8,1),(8,7),(7,8)],75:[(7,0),(8,1),(8,7),(7,8)],76:[(7,0),(8,1),(8,7),(7,8)],77:[(7,0),(8,1),(8,7),(7,8)],
    #         78:[(8,0),(8,8)],79:[(8,0),(8,8)]
    #         }
    # hope = {0:[(0,3),(0,5),(1,4)],1:[(0,3),(0,5),(1,4)],2:[(0,3),(0,5),(1,4)],
    #         3:[(0,6),(1,5),(0,2),(1,3),(2,4)],4:[(0,6),(1,5),(0,2),(1,3),(2,4)],5:[(0,6),(1,5),(0,2),(1,3),(2,4)],6:[(0,6),(1,5),(0,2),(1,3),(2,4)],7:[(0,6),(1,5),(0,2),(1,3),(2,4)],
    #         8:[(0,1),(1,2),(2,3),(0,7),(1,6),(2,5),(3,4)],9:[(0,1),(1,2),(2,3),(0,7),(1,6),(2,5),(3,4)],10:[(0,1),(1,2),(2,3),(0,7),(1,6),(2,5),(3,4)],11:[(0,1),(1,2),(2,3),(0,7),(1,6),(2,5),(3,4)],12:[(0,1),(1,2),(2,3),(0,7),(1,6),(2,5),(3,4)],13:[(0,1),(1,2),(2,3),(0,7),(1,6),(2,5),(3,4)],14:[(0,1),(1,2),(2,3),(0,7),(1,6),(2,5),(3,4)],
    #     6:[(0,1),(3,4),(0,7)],7:[(0,1),(3,4),(0,7)],8:[(0,1),(3,4),(0,7)],
    #     9:[(0,0),(4,4),(0,8)],10:[(0,0),(4,4),(0,8)],11:[(0,0),(4,4),(0,8)],
    #     12:[(1,3),(1,5)],13:[(1,3),(1,5)],
    #     14:[(2,3),(2,5)],15:[(2,3),(2,5)],
    #     16:[(2,2),(2,6)],17:[(2,2),(2,6)],
    #     18:[(2,1),(2,7)],19:[(2,1),(2,7)],
    #     20:[(2,0),(2,8)],21:[(2,0),(2,8)],
    #     22:[(3,3),(3,5)],23:[(3,3),(3,5)],
    #     24:[(4,3),(5,4),(4,5)],25:[(4,3),(5,4),(4,5)],26:[(4,3),(5,4),(4,5)],
    #     27:[(4,2),(6,4),(4,6)],28:[(4,2),(6,4),(4,6)],29:[(4,2),(6,4),(4,6)],
    #     30:[(4,1),(7,4),(4,7)],31:[(4,1),(7,4),(4,7)],32:[(4,1),(7,4),(4,7)],
    #     33:[(4,0),(8,4),(4,8)],34:[(4,0),(8,4),(4,8)],35:[(4,0),(8,4),(4,8)],
    #     36:[(5,3),(5,5)],37:[(5,3),(5,5)],
    #     38:[(6,3),(6,5)],39:[(6,3),(6,5)],
    #     40:[(6,2),(6,6)],41:[(6,2),(6,6)],
    #     42:[(6,1),(6,7)],43:[(6,1),(6,7)],
    #     44:[(6,0),(6,8)],45:[(6,0),(6,8)],
    #     46:[(7,3),(7,5)],47:[(7,3),(7,5)],
    #     48:[(8,3),(8,5)],49:[(8,3),(8,5)],
    #     50:[(8,2),(8,6)],51:[(8,2),(8,6)],
    #     52:[(8,1),(8,7)],53:[(8,1),(8,7)],
    #     54:[(8,0),(8,8)],55:[(8,0),(8,8)],
    #     56:[(1,2),(1,6)],57:[(1,2),(1,6)],
    #     58:[(1,1),(1,7)],59:[(1,1),(1,7)],
    #     60:[(1,0),(1,8)],61:[(1,0),(1,8)],
    #     62:[(3,2),(3,6)],63:[(3,2),(3,6)],
    #     64:[(3,1),(3,7)],65:[(3,1),(3,7)],
    #     66:[(3,0),(3,8)],67:[(3,0),(3,8)],
    #     68:[(5,2),(5,6)],69:[(5,2),(5,6)],
    #     70:[(5,1),(5,7)],71:[(5,1),(5,7)],
    #     72:[(5,0),(5,8)],73:[(5,0),(5,8)],
    #     74:[(7,2),(7,6)],75:[(7,2),(7,6)],
    #     76:[(7,1),(7,7)],77:[(7,1),(7,7)],
    #     78:[(7,0),(7,8)],79:[(7,0),(7,8)]
    # }
    # hope = {0:[(0,3),(1,4)],1:[(0,3),(1,4)],2:[(0,3),(1,4)],
    #         3:[(0,2),(1,3),(2,4)],4:[(0,2),(1,3),(2,4)],5:[(0,2),(1,3),(2,4)],6:[(0,2),(1,3),(2,4)],7:[(0,2),(1,3),(2,4)],
    #         8:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],9:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],10:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],11:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],12:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],13:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],14:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],
    #         15:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],16:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],17:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],18:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],19:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],20:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],21:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],22:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],23:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],
    #         24:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],25:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],26:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],27:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],28:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],29:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],30:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],31:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],32:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],
    #         33:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],34:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],35:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],36:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],37:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],38:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],39:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],40:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],41:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],
    #         42:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],43:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],44:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],45:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],46:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],47:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],48:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],49:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],50:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],
    #         51:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],52:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],53:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],54:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],55:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],56:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],57:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],58:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],59:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],
    #         60:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],61:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],62:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],63:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],64:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],65:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],66:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],67:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],
    #         68:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],69:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],70:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],71:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],72:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],73:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],
    #         74:[(7,0),(8,1),(8,7),(7,8)],75:[(7,0),(8,1),(8,7),(7,8)],76:[(7,0),(8,1),(8,7),(7,8)],77:[(7,0),(8,1),(8,7),(7,8)],
    #         78:[(8,0),(8,8)],79:[(8,0),(8,8)]
    #         }
    # hope = {0:[(0,3),(1,4)],1:[(0,3),(1,4)],2:[(0,3),(1,4)],
    #         3:[(0,2),(1,3),(2,4)],4:[(0,2),(1,3),(2,4)],5:[(0,2),(1,3),(2,4)],6:[(0,2),(1,3),(2,4)],7:[(0,2),(1,3),(2,4)],
    #         8:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],9:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],10:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],11:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],12:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],13:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],14:[(0,1),(1,2),(2,3),(3,4),(2,5),(1,6),(0,7)],
    #         15:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],16:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],17:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],18:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],19:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],20:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],21:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],22:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],23:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],
    #         24:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],25:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],26:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],27:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],28:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],29:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],30:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],31:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],32:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],
    #         33:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],34:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],35:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],36:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],37:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],38:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],39:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],40:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],41:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],
    #         42:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],43:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],44:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],45:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],46:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],47:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],48:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],49:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],50:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],
    #         51:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],52:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],53:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],54:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],55:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],56:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],57:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],58:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],59:[(4,0),(5,1),(6,2),(7,3),(8,4),(7,5),(6,6),(5,7),(4,8)],
    #         60:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],61:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],62:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],63:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],64:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],65:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],66:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],67:[(5,0),(6,1),(7,2),(8,3),(8,5),(7,6),(6,7),(5,8)],
    #         68:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],69:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],70:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],71:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],72:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],73:[(6,0),(7,1),(8,2),(8,6),(7,7),(6,8)],
    #         74:[(7,0),(8,1),(8,7),(7,8),(8,0),(8,8),(0,8),(0,7),(1,8)],75:[(7,0),(8,1),(8,7),(7,8),(8,0),(8,8),(0,8),(0,7),(1,8)],76:[(7,0),(8,1),(8,7),(7,8),(8,0),(8,8),(0,8),(0,7),(1,8)],77:[(7,0),(8,1),(8,7),(7,8),(8,0),(8,8),(0,8),(0,7),(1,8)],
    #         78:[(8,0),(8,8),(0,8),(0,7),(1,8)],79:[(8,0),(8,8),(0,8),(0,7),(1,8)]
    #         }
    # (1,6),(0,7)
    # hope = {0:[(0,3),(1,4)],1:[(0,3),(1,4)],2:[(0,3),(1,4)],
    #         3:[(0,2),(1,3),(2,4)],4:[(0,2),(1,3),(2,4)],5:[(0,2),(1,3),(2,4)],6:[(0,2),(1,3),(2,4)],7:[(0,2),(1,3),(2,4)],
    #         8:[(0,1),(1,2),(2,3),(3,4),(2,5)],9:[(0,1),(1,2),(2,3),(3,4),(2,5)],10:[(0,1),(1,2),(2,3),(3,4),(2,5)],11:[(0,1),(1,2),(2,3),(3,4),(2,5)],12:[(0,1),(1,2),(2,3),(3,4),(2,5)],13:[(0,1),(1,2),(2,3),(3,4),(2,5)],14:[(0,1),(1,2),(2,3),(3,4),(2,5)],
    #         15:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],16:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],17:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],18:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],19:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],20:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],21:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],22:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],23:[(0,0),(1,1),(2,2),(3,3),(4,4),(3,5),(2,6),(1,7),(0,8)],
    #         24:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],25:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],26:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],27:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],28:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],29:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],30:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],31:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],32:[(1,0),(2,1),(3,2),(4,3),(5,4),(4,5),(3,6),(2,7),(1,8)],
    #         33:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],34:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],35:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],36:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],37:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],38:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],39:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],40:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],41:[(2,0),(3,1),(4,2),(5,3),(6,4),(5,5),(4,6),(3,7),(2,8)],
    #         42:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],43:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)],44:[(3,0),(4,1),(5,2),(6,3),(7,4),(6,5),(5,6),(4,7),(3,8)
            78:[(8,0),(8,8),(0,8),(0,7),(1,8)],79:[(8,0),(8,8),(0,8),(0,7),(1,8)]
            }
    for _ in [0]*N:
        # 壁の座標
        ri,rj = map(int,input().split())
        souko[ri+1][rj+1] = -1
    for _ in [0]*(80-N):
        # 運び込まれるコンテナ番号
        con = int(input())
        # コンテナを格納したい場所の候補
        h_list = hope[con]
        # コンテナを格納したい場所の候補の中で，空いている場所を探す
        h_can_list = []
        for h in h_list:
            if souko[h[0]+1][h[1]+1] == -2:
                h_can_list.append(h)
        # 空いている場所にコンテナを格納した場合，入口(1,5)から到達できるマスの数が空きマスの数と同じならば，その場所にコンテナを格納する
        for h_can in h_can_list:
            # h_canにコンテナを格納した場合の倉庫の状態を作る
            souko[h_can[0]+1][h_can[1]+1] = con
            # 入口から到達できるマスの座標
            can_q = deque([(1,5)])
            # 到達したマスの集合
            can_set = set([(1,5)])
            # 入口から到達できるマスの座標を探索
            while can_q:
                i,j = can_q.pop()
                if souko[i][j] == -2:
                    # 上下左右のマスを探索
                    if souko[i-1][j] == -2 and (i-1,j) not in can_set:
                        can_q.append((i-1,j))
                        can_set.add((i-1,j))
                    if souko[i+1][j] == -2 and (i+1,j) not in can_set:
                        can_q.append((i+1,j))
                        can_set.add((i+1,j))
                    if souko[i][j-1] == -2 and (i,j-1) not in can_set:
                        can_q.append((i,j-1))
                        can_set.add((i,j-1))
                    if souko[i][j+1] == -2 and (i,j+1) not in can_set:
                        can_q.append((i,j+1))
                        can_set.add((i,j+1))
            if len(can_set) == space-1:
                # 入口から到達できるマスの数が空きマスの数と同じならば，その場所にコンテナを格納してあるから次のコンテナへ
                print(*h_can, flush=True)
                space -= 1
                break
            else:
                # 空きマスに戻す
                souko[h_can[0]+1][h_can[1]+1] = -2
        else:
            k = 0
            # 格納できたかどうか
            flag = True
            while True:
                h_list = hope[con+k]
                if con == 79:
                    flag = False
                    break
                while h_list == hope[con+k]:
                    k += 1
                    if con+k == 80:
                        flag = False
                        break
                if not flag:
                    break
                h_list = hope[con+k]
                # コンテナを格納したい場所の候補の中で，空いている場所を探す
                h_can_list = []
                for h in h_list:
                    if souko[h[0]+1][h[1]+1] == -2:
                        h_can_list.append(h)
                # 空いている場所にコンテナを格納した場合，入口(1,5)から到達できるマスの数が空きマスの数と同じならば，その場所にコンテナを格納する
                for h_can in h_can_list:
                    # h_canにコンテナを格納した場合の倉庫の状態を作る
                    souko[h_can[0]+1][h_can[1]+1] = con
                    # 入口から到達できるマスの座標
                    can_q = deque([(1,5)])
                    # 到達したマスの集合
                    can_set = set([(1,5)])
                    # 入口から到達できるマスの座標を探索
                    while can_q:
                        i,j = can_q.pop()
                        if souko[i][j] == -2:
                            # 上下左右のマスを探索
                            if souko[i-1][j] == -2 and (i-1,j) not in can_set:
                                can_q.append((i-1,j))
                                can_set.add((i-1,j))
                            if souko[i+1][j] == -2 and (i+1,j) not in can_set:
                                can_q.append((i+1,j))
                                can_set.add((i+1,j))
                            if souko[i][j-1] == -2 and (i,j-1) not in can_set:
                                can_q.append((i,j-1))
                                can_set.add((i,j-1))
                            if souko[i][j+1] == -2 and (i,j+1) not in can_set:
                                can_q.append((i,j+1))
                                can_set.add((i,j+1))
                    if len(can_set) == space-1:
                        # 入口から到達できるマスの数が空きマスの数と同じならば，その場所にコンテナを格納してあるから次のコンテナへ
                        print(*h_can, flush=True)
                        space -= 1
                        break
                    else:
                        # 空きマスに戻す
                        souko[h_can[0]+1][h_can[1]+1] = -2
                else:
                    # h_can_listの中にコンテナを置ける場所がなかったなら，奥のh_listを探索する
                    continue
                # コンテナを置けたなら，次のコンテナへ
                break
            # 一番奥に置く
            if not flag:
                # BFSで一番奥の空きマスを探索
                last_node = tuple()
                # 入口から到達できるマスの座標
                can_q = deque([(1,5)])
                # 到達したマスの集合
                can_set = set([(1,5)])
                # 入口から到達できるマスの座標を探索
                while can_q:
                    i,j = can_q.popleft()
                    if souko[i][j] == -2:
                        # 上下左右のマスを探索
                        if souko[i-1][j] == -2 and (i-1,j) not in can_set:
                            can_q.append((i-1,j))
                            can_set.add((i-1,j))
                        if souko[i+1][j] == -2 and (i+1,j) not in can_set:
                            can_q.append((i+1,j))
                            can_set.add((i+1,j))
                        if souko[i][j-1] == -2 and (i,j-1) not in can_set:
                            can_q.append((i,j-1))
                            can_set.add((i,j-1))
                        if souko[i][j+1] == -2 and (i,j+1) not in can_set:
                            can_q.append((i,j+1))
                            can_set.add((i,j+1))
                    if len(can_q) == 0:
                        last_node = (i-1,j-1)
                        break
                # 一番奥の空きマスにコンテナを格納
                souko[last_node[0]+1][last_node[1]+1] = con
                print(*last_node, flush=True)
                space -= 1
    # 入口から到達できるコンテナのうち最小の番号のコンテナの座標を出力する
    for _ in [0]*80:
        # 到達できる最小のコンテナ番号とその座標
        min_con = 100
        min_node = tuple()
        # 入口(1,5)から到達できるコンテナの番号の座標を探索
        can_q = deque([(1,5)])
        # 到達したマスの集合
        can_set = set([(1,5)])
        # 入口から到達できるマスの座標を探索
        while can_q:
            i,j = can_q.pop()
            if souko[i][j] == -2:
                # 上下左右のマスを探索
                if souko[i-1][j] == -2 and (i-1,j) not in can_set:
                    can_q.append((i-1,j))
                    can_set.add((i-1,j))
                elif souko[i-1][j] >= 0 and souko[i-1][j] < min_con:
                    min_con = souko[i-1][j]
                    min_node = (i-1,j)
                if souko[i+1][j] == -2 and (i+1,j) not in can_set:
                    can_q.append((i+1,j))
                    can_set.add((i+1,j))
                elif souko[i+1][j] >= 0 and souko[i+1][j] < min_con:
                    min_con = souko[i+1][j]
                    min_node = (i+1,j)
                if souko[i][j-1] == -2 and (i,j-1) not in can_set:
                    can_q.append((i,j-1))
                    can_set.add((i,j-1))
                elif souko[i][j-1] >= 0 and souko[i][j-1] < min_con:
                    min_con = souko[i][j-1]
                    min_node = (i,j-1)
                if souko[i][j+1] == -2 and (i,j+1) not in can_set:
                    can_q.append((i,j+1))
                    can_set.add((i,j+1))
                elif souko[i][j+1] >= 0 and souko[i][j+1] < min_con:
                    min_con = souko[i][j+1]
                    min_node = (i,j+1)
        print(min_node[0]-1,min_node[1]-1, flush=True)
        souko[min_node[0]][min_node[1]] = -2
    
if __name__ == "__main__":
    main()
