# %%
from collections import deque
from collections import Counter
import numpy as np

def main():
    f1_100 = input().split()
    f1_100_int = []
    one = 0
    two = 0
    thr = 0
    for i in f1_100:
        if i == "1":
            one += 1
        elif i == "2":
            two += 1
        else:
            thr += 1
        f1_100_int.append(int(i))
        
    d_one = "F"
    d_two = "F"
    d_thr = "F"
    if one >= two:
        d_one = "R"
        if two >= thr:
            d_two = "L"
        else:
            d_thr = "L"
    else:
        d_two = "R"
        if one >= thr:
            d_one = "L"
        else:
            d_thr = "L"
    
    bef = "B"
    for i in range(100):
        input()
        if i == 99:
            print("B")
        else:
            nex = f1_100_int[i+1]
            if nex == 1:
                if bef == d_one:
                    print("F", flush=True)
                else:
                    print(d_one, flush=True)
                bef = d_one
            elif nex == 2:
                if bef == d_two:
                    print("F", flush=True)
                else:
                    print(d_two, flush=True)
                bef = d_two
            elif nex == 3:
                if bef == d_thr:
                    print("F", flush=True)
                else:
                    print(d_thr, flush=True)
                bef = d_thr
        
    
if __name__ == "__main__":
    main()
# Out:
# 2 2 1 3 1 2 1 2 1 3 2 1 3 3 1 1 3 2 1 2 2 1 1 1 2 2 2 1 3 3 2 3 3 1 3 3 3 2 3 3 2 2 1 1 2 1 1 3 2 1 1 1 2 1 2 3 3 1 2 2 3 1 3 1 1 3 2 3 1 2 2 1 3 1 2 2 2 2 1 3 2 1 2 1 2 3 2 1 2 1 3 2 3 3 1 1 1 3 2 3
# L
# R
# F
# R
# L
# R
# L
# R
# F
# L
# R
# F
# F
# R
# F
# F
# L
# R
# L
# F
# R
# F
# F
# L
# F
# F
# R
# F
# F
# L
# F
# F
# R
# F
# F
# F
# L
# F
# F
# L
# F
# R
# F
# L
# R
# F
# F
# L
# R
# F
# F
# L
# R
# L
# F
# F
# R
# L
# F
# F
# R
# F
# R
# F
# F
# L
# F
# R
# L
# F
# R
# F
# R
# L
# F
# F
# F
# R
# F
# L
# R
# L
# R
# L
# F
# L
# R
# L
# R
# F
# L
# F
# F
# R
# F
# F
# F
# L
# F
# B

# %%
from collections import deque
from collections import Counter
import numpy as np

def main():
    f1_100 = input().split()
    f1_100_int = []
    one = 0
    two = 0
    thr = 0
    for i in f1_100:
        if i == "1":
            one += 1
        elif i == "2":
            two += 1
        else:
            thr += 1
        f1_100_int.append(int(i))
        
    d_one = "F"
    d_two = "F"
    d_thr = "F"
    if one >= two:
        d_one = "R"
        if two >= thr:
            d_two = "L"
        else:
            d_thr = "L"
    else:
        d_two = "R"
        if one >= thr:
            d_one = "L"
        else:
            d_thr = "L"
    
    bef = "B"
    R_L = "R"
    for i in range(100):
        input()
        if i == 99:
            print("B")
        else:
            nex = f1_100_int[i+1]
            if nex == 1:
                if bef == d_one:
                    if d_one == "F":
                        print(R_L, flush=True)
                    else:
                        print("F", flush=True)
                else:
                    print(d_one, flush=True)
                bef = d_one
                if d_one =="R" or d_one == "L":
                    R_L = d_one
            elif nex == 2:
                if bef == d_two:
                    if d_two == "F":
                        print(R_L, flush=True)
                    else:
                        print("F", flush=True)
                else:
                    print(d_two, flush=True)
                bef = d_two
                if d_two =="R" or d_two == "L":
                    R_L = d_two
            elif nex == 3:
                if bef == d_thr:
                    if d_thr == "F":
                        print(R_L, flush=True)
                    else:
                        print("F", flush=True)
                else:
                    print(d_thr, flush=True)
                bef = d_thr
                if d_thr =="R" or d_thr == "L":
                    R_L = d_thr
    
if __name__ == "__main__":
    main()
# Out:
# 2 2 1 3 1 2 1 2 1 3 2 1 3 3 1 1 3 2 1 2 2 1 1 1 2 2 2 1 3 3 2 3 3 1 3 3 3 2 3 3 2 2 1 1 2 1 1 3 2 1 1 1 2 1 2 3 3 1 2 2 3 1 3 1 1 3 2 3 1 2 2 1 3 1 2 2 2 2 1 3 2 1 2 1 2 3 2 1 2 1 3 2 3 3 1 1 1 3 2 3
# L
# R
# F
# R
# L
# R
# L
# R
# F
# L
# R
# F
# R
# R
# F
# F
# L
# R
# L
# F
# R
# F
# F
# L
# F
# F
# R
# F
# R
# L
# F
# L
# R
# F
# R
# R
# L
# F
# L
# L
# F
# R
# F
# L
# R
# F
# F
# L
# R
# F
# F
# L
# R
# L
# F
# L
# R
# L
# F
# F
# R
# F
# R
# F
# F
# L
# F
# R
# L
# F
# R
# F
# R
# L
# F
# F
# F
# R
# F
# L
# R
# L
# R
# L
# F
# L
# R
# L
# R
# F
# L
# F
# L
# R
# F
# F
# F
# L
# F
# B

# %%
from collections import deque
from collections import Counter
import numpy as np

def main():
    f1_100 = input().split()
    f1_100_int = []
    one = 0
    two = 0
    thr = 0
    for i in f1_100:
        if i == "1":
            one += 1
        elif i == "2":
            two += 1
        else:
            thr += 1
        f1_100_int.append(int(i))
        
    d_one = "F"
    d_two = "F"
    d_thr = "F"
    if one >= two and one >= thr:
        d_two = "R"
        d_thr = "L"
    elif two >= one and two >= thr:
        d_one = "R"
        d_thr = "L"
    else:
        d_one = "R"
        d_two = "L"
    
    bef = "B"
    for i in range(100):
        input()
        if i == 99:
            print("B")
        else:
            nex = f1_100_int[i+1]
            if nex == 1:
                if d_one == "F":
                    print(d_one, flush=True)
                    bef = d_one
                else:
                    if bef == "F":
                        print("B", flush=True)
                        bef = "B"
                    else:
                        if bef == d_one:
                            print("B", flush=True)
                        else:
                            print(d_one, flush=True)
                            bef = d_one
            elif nex == 2:
                if d_two == "F":
                    print(d_two, flush=True)
                    bef = d_two
                else:
                    if bef == "F":
                        print("B", flush=True)
                        bef = "B"
                    else:
                        if bef == d_two:
                            print("B", flush=True)
                        else:
                            print(d_two, flush=True)
                            bef = d_two
            elif nex == 3:
                if d_thr == "F":
                    print(d_thr, flush=True)
                    bef = d_thr
                else:
                    if bef == "F":
                        print("B", flush=True)
                        bef = "B"
                    else:
                        if bef == d_thr:
                            print("B", flush=True)
                        else:
                            print(d_thr, flush=True)
                            bef = d_thr
        
    
if __name__ == "__main__":
    main()
# Out:
# 2 2 1 3 1 2 1 2 1 3 2 1 3 3 1 1 3 2 1 2 2 1 1 1 2 2 2 1 3 3 2 3 3 1 3 3 3 2 3 3 2 2 1 1 2 1 1 3 2 1 1 1 2 1 2 3 3 1 2 2 3 1 3 1 1 3 2 3 1 2 2 1 3 1 2 2 2 2 1 3 2 1 2 1 2 3 2 1 2 1 3 2 3 3 1 1 1 3 2 3
# R
# F
# B
# F
# B
# F
# B
# F
# B
# R
# F
# B
# L
# F
# F
# B
# R
# F
# B
# R
# F
# F
# F
# B
# R
# B
# F
# B
# L
# R
# L
# B
# F
# B
# L
# B
# R
# L
# B
# R
# B
# F
# F
# B
# F
# F
# B
# R
# F
# F
# F
# B
# F
# B
# L
# B
# F
# B
# R
# L
# F
# B
# F
# F
# B
# R
# L
# F
# B
# R
# F
# B
# F
# B
# R
# B
# B
# F
# B
# R
# F
# B
# F
# B
# L
# R
# F
# B
# F
# B
# R
# L
# B
# F
# F
# F
# B
# R
# L
# B

# %%
from collections import deque
from collections import Counter
import numpy as np

def main():
    f1_100 = input().split()
    f1_100_int = []
    one = 0
    two = 0
    thr = 0
    for i in f1_100:
        if i == "1":
            one += 1
        elif i == "2":
            two += 1
        else:
            thr += 1
        f1_100_int.append(int(i))
        
    d_one = "F"
    d_two = "F"
    d_thr = "F"
    if one >= two and one >= thr:
        d_two = "R"
        d_thr = "L"
    elif two >= one and two >= thr:
        d_one = "R"
        d_thr = "L"
    else:
        d_one = "R"
        d_two = "L"
    
    bef = "B"
    R_L = "B"
    for i in range(100):
#         input()
        if i == 99:
            print("B")
        else:
            nex = f1_100_int[i+1]
            if nex == 1:
                if d_one == "F":
                    print(d_one, flush=True)
                    bef = d_one
                else:
                    if bef == "F":
                        print("B", flush=True)
                        bef = "B"
                    else:
                        if R_L == d_one:
                            if f1_100_int[i] == nex:
                                print("B", flush=True)
                            else:
                                print(d_one, flush=True)
                                bef = d_one
                        else:
                            print(d_one, flush=True)
                            bef = d_one
                        R_L = d_one
            elif nex == 2:
                if d_two == "F":
                    print(d_two, flush=True)
                    bef = d_two
                else:
                    if bef == "F":
                        print("B", flush=True)
                        bef = "B"
                    else:
                        if R_L == d_two:
                            if f1_100_int[i] == nex:
                                print("B", flush=True)
                            else:
                                print(d_two, flush=True)
                                bef = d_two
                        else:
                            print(d_two, flush=True)
                            bef = d_two
                        R_L = d_two
            elif nex == 3:
                if d_thr == "F":
                    print(d_thr, flush=True)
                    bef = d_thr
                else:
                    if bef == "F":
                        print("B", flush=True)
                        bef = "B"
                    else:
                        if R_L == d_thr:
                            if f1_100_int[i] == nex:
                                print("B", flush=True)
                            else:
                                print(d_thr, flush=True)
                                bef = d_thr
                        else:
                            print(d_thr, flush=True)
                            bef = d_thr
                        R_L = d_thr
        
    
if __name__ == "__main__":
    main()
# Out:
# 2 2 1 3 1 2 1 2 1 3 2 1 3 3 1 1 3 2 1 2 2 1 1 1 2 2 2 1 3 3 2 3 3 1 3 3 3 2 3 3 2 2 1 1 2 1 1 3 2 1 1 1 2 1 2 3 3 1 2 2 3 1 3 1 1 3 2 3 1 2 2 1 3 1 2 2 2 2 1 3 2 1 2 1 2 3 2 1 2 1 3 2 3 3 1 1 1 3 2 3
# R
# F
# B
# F
# B
# F
# B
# F
# B
# R
# F
# B
# L
# F
# F
# B
# R
# F
# B
# B
# F
# F
# F
# B
# B
# B
# F
# B
# L
# R
# L
# B
# F
# B
# B
# B
# R
# L
# B
# R
# B
# F
# F
# B
# F
# F
# B
# R
# F
# F
# F
# B
# F
# B
# L
# B
# F
# B
# R
# L
# F
# B
# F
# F
# B
# R
# L
# F
# B
# R
# F
# B
# F
# B
# B
# B
# B
# F
# B
# R
# F
# B
# F
# B
# L
# R
# F
# B
# F
# B
# R
# L
# B
# F
# F
# F
# B
# R
# L
# B

# %%
379536
593099
875669
852469
