# %%
from functools import lru_cache
import sys
sys.setrecursionlimit(10**9)
# input = sys.stdin.readline
from decimal import Decimal
from functools import cmp_to_key
from collections import Counter
from itertools import permutations
from itertools import combinations
from itertools import combinations_with_replacement
from copy import deepcopy
import math
import heapq
from collections import OrderedDict
import bisect
from collections import deque
from collections import defaultdict

def main():
    N,X = map(int,input().split())
    lv_to_maisuu = defaultdict(int)
    # パティは枚数//2+1枚
    lv_to_maisuu[0] = 1
    for i in range(1,N+1):
        lv_to_maisuu[i] = lv_to_maisuu[i-1]*2+3
    # 二分探索して右なら左のパティの枚数を足す
    l = 1
    r = lv_to_maisuu[N]
    i = 0
    ans = 0
    while l <= r:
        if l == r:
            if l <= X:
                ans += 1
                break
        i += 1
        m = (l+r)//2
        if m == X:
            if lv_to_maisuu[N-i] != 0:
                ans += lv_to_maisuu[N-i]//2+2
            break
        elif m < X:
            l = m+1
            r -= 1
            if lv_to_maisuu[N-i] != 0:
                ans += lv_to_maisuu[N-i]//2+2
        else:
            r = m-1
            l += 1
    print(ans)
    
if __name__ == "__main__":
    main()
# Out:
# 2251799813685247
# 3377699720527870
# 3940649673949182
# 4222124650659838
# 4362862139015166
# 4292493394837502
# 4327677766926334
# 4310085580881918
# 4318881673904126
# 4323279720415230
# 4321080697159678
# 4322180208787454
# 4321630452973566
# 4321355575066622
# 4321218136113150
# 4321149416636414
# 4321115056898046
# 4321097877028862
# 4321106466963454
# 4321102171996158
# 4321100024512510
# 4321098950770686
# 4321098413899774
# 4321098682335230
# 4321098816552958
# 4321098749444094
# 4321098782998526
# 4321098766221310
# 4321098757832702
# 4321098762027006
# 4321098764124158
# 4321098765172734
# 4321098765697022
# 4321098765434878
# 4321098765303806
# 4321098765369342
# 4321098765402110
# 4321098765418494
# 4321098765426686
# 4321098765430782
# 4321098765432830
# 4321098765431806
# 4321098765432318
# 4321098765432062
# 4321098765432190
# 4321098765432126
# 4321098765432094
# 4321098765432110
# 4321098765432102
# 4321098765432106
# 4321098765432108
# 4321098765432109
# 2160549382716000
